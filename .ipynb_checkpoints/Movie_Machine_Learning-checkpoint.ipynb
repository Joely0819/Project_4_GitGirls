# %% [markdown]
# # TMDB Box Office Predictions
# In this project, we will use supervised machine learning models to predict the box office revenue of hundreds of films

# %% [markdown]
# # API Pull
# To retrieve our dataset, we will conduct an API pull from the TMDB website
# https://www.themoviedb.org/

# %%
#import dependencies 
import pandas as pd
import numpy as np
from config import api_key
import json
from collections import Counter
from pprint import pprint
import requests
import os 
import csv

# %% [markdown]
# Data for 2020

# %%
#Kaggle Dataset Provides us with movie info up until 2019
#to keep project up to date, we will preform API pulls for 2020 and 2021 films

# %%
#The tmdb only allows API pulls for 1 page at a time 
#page 1 url
#we will pull the 1st 10 pages of each year with descending revenue
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=1')

# %%
highest_revenue = response.json() # store parsed json response

# uncomment the next line to get a peek at the highest_revenue json structure
# highest_revenue

highest_revenue_films = highest_revenue['results']

# %%
# define column names for our new dataframe
columns = ['film', 'budget', 'genres', 'original_language', 'popularity', 'production_companies', 
           'release_date', 'runtime','revenue']

# create dataframe with film and revenue columns
df_2020 = pd.DataFrame(columns=columns)

# %%
# for each of the highest revenue films make an api call for that specific movie to return all of our column headers
for film in highest_revenue_films:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020.loc[len(df_2020)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page 2
response2 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=2')

# %%
two= response2.json()
page_two = two['results']

# %%
df_2020_2 = pd.DataFrame(columns=columns)

# %%
# for each of the highest revenue films make an api call for that specific movie to return all of our column headers
for film in page_two:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_2.loc[len(df_2020_2)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page 3
response3 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=3')
three= response3.json()
page_three = three['results']

# %%
df_2020_3 = pd.DataFrame(columns=columns)

# %%
for film in page_three:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_3.loc[len(df_2020_3)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#Page 4
response4 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=4')
four= response4.json()
page_four = four['results']
df_2020_4 = pd.DataFrame(columns=columns)

# %%
for film in page_four:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_4.loc[len(df_2020_4)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page5
response5 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=5')
five= response5.json()
page_five = five['results']
df_2020_5 = pd.DataFrame(columns=columns)

# %%
for film in page_five:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_5.loc[len(df_2020_5)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page6
response6 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=6')
six= response6.json()
page_six = six['results']
df_2020_6 = pd.DataFrame(columns=columns)

# %%
for film in page_six:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_6.loc[len(df_2020_6)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page7
response7 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=7')
seven= response7.json()
page_seven = seven['results']
df_2020_7 = pd.DataFrame(columns=columns)

# %%
for film in page_seven:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_7.loc[len(df_2020_7)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page8
response8 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=8')
eight= response8.json()
page_eight = eight['results']
df_2020_8 = pd.DataFrame(columns=columns)

# %%
for film in page_eight:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_8.loc[len(df_2020_8)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page9
response9 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=9')
nine= response9.json()
page_nine = nine['results']
df_2020_9 = pd.DataFrame(columns=columns)

# %%
for film in page_nine:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_9.loc[len(df_2020_9)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page10
response10 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2020&sort_by=revenue.desc'+'&page=10')
ten= response10.json()
page_ten = ten['results']
df_2020_10 = pd.DataFrame(columns=columns)

# %%
for film in page_ten:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2020_10.loc[len(df_2020_10)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#Combine all 10 2020 movie dfs 
Total_2020_Movies= pd.concat([df_2020, df_2020_2, df_2020_3, df_2020_4, df_2020_5, df_2020_6,
          df_2020_7, df_2020_8, df_2020_9, df_2020_10], ignore_index=True, axis=0)

# %% [markdown]
# Data for 2021

# %%
#page1
response1a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=1')
onea= response1a.json()
page_onea = onea['results']
df_2021 = pd.DataFrame(columns=columns)

# %%
for film in page_onea:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021.loc[len(df_2021)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page2
response2a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
twoa= response2a.json()
page_twoa = twoa['results']
df_2021_2 = pd.DataFrame(columns=columns)

# %%
for film in page_twoa:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_2.loc[len(df_2021_2)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page3
response3a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
threea= response3a.json()
page_threea = threea['results']
df_2021_3 = pd.DataFrame(columns=columns)

# %%
for film in page_threea:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_3.loc[len(df_2021_3)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page4
response4a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
foura= response4a.json()
page_foura = foura['results']
df_2021_4 = pd.DataFrame(columns=columns)

# %%
for film in page_foura:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_4.loc[len(df_2021_4)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page5
response5a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
fivea= response5a.json()
page_fivea = fivea['results']
df_2021_5 = pd.DataFrame(columns=columns)

# %%
for film in page_twoa:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_5.loc[len(df_2021_5)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page6
response6a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
sixa= response6a.json()
page_sixa = sixa['results']
df_2021_6 = pd.DataFrame(columns=columns)

# %%
for film in page_sixa:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_6.loc[len(df_2021_6)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page7
response7a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
sevena= response7a.json()
page_sevena = sevena['results']
df_2021_7 = pd.DataFrame(columns=columns)

# %%
for film in page_sevena:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_7.loc[len(df_2021_7)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page8
response8a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
eighta= response8a.json()
page_eighta = eighta['results']
df_2021_8 = pd.DataFrame(columns=columns)

# %%
for film in page_eighta:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_8.loc[len(df_2021_8)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page9
response9a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
ninea= response9a.json()
page_ninea = ninea['results']
df_2021_9 = pd.DataFrame(columns=columns)

# %%
for film in page_ninea:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_9.loc[len(df_2021_9)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#page10
response10a = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&primary_release_year=2021&sort_by=revenue.desc'+'&page=2')
tena= response10a.json()
page_tena = tena['results']
df_2021_10 = pd.DataFrame(columns=columns)

# %%
for film in page_tena:
    # print(film['title'])
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    #print(locale.currency(film_revenue['revenue'], grouping=True ))
    df_2021_10.loc[len(df_2021_10)]=[film['title'],film_revenue['budget'],film_revenue['genres'],
                     film_revenue['original_language'],film_revenue['popularity'],
                     film_revenue['production_companies'],film_revenue['release_date'],film_revenue['runtime'],
                     film_revenue['revenue']] # store title and revenue in our dataframe

# %%
#Combine all 10 2021 movie dfs 
Total_2021_Movies = pd.concat([df_2021, df_2021_2, df_2021_3, df_2021_4, df_2021_5, df_2021_6,
          df_2021_7, df_2021_8, df_2021_9, df_2021_10], ignore_index=True, axis=0)

# %%
#View your dataframes
Total_2020_Movies
# Out:
#                                                   film     budget  \
# 0    Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...   15800000
# 1                                    The Eight Hundred   80000000
# 2    Metallica: WorldWired Tour - Live in Mancheste...          0
# 3                                    Bad Boys for Life   90000000
# 4                                                Tenet  205000000
# ..                                                 ...        ...
# 195                                    Force of Nature          0
# 196                                          Two of Us          0
# 197                                      The Predators          0
# 198                                      Ghosts of War          0
# 199                                       Irresistible          0
#
#                                                 genres original_language  \
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 28, '...                ja
# 1    [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...                zh
# 2                     [{'id': 10402, 'name': 'Music'}]                en
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...                en
# 4    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                en
# ..                                                 ...               ...
# 195  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 196  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                fr
# 197  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...                it
# 198  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 199  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
#
#      popularity                               production_companies  \
# 0      1169.173  [{'id': 5887, 'logo_path': '/m6FEqz8rQECnmfjEw...
# 1        17.175  [{'id': 112270, 'logo_path': None, 'name': 'Be...
# 2         3.878                                                 []
# 3        84.824  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 4       106.663  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# ..          ...                                                ...
# 195      18.887  [{'id': 290, 'logo_path': '/Q8mw2AOQQc8Qg0uNwL...
# 196       8.225  [{'id': 11010, 'logo_path': None, 'name': 'Pap...
# 197       9.487  [{'id': 2441, 'logo_path': '/7Vutdea75apwXkRyf...
# 198      41.626  [{'id': 46240, 'logo_path': '/8jiwvypPWazxmJcY...
# 199      12.477  [{'id': 10146, 'logo_path': '/xnFIOeq5cKw09kCW...
#
#     release_date runtime    revenue
# 0     2020-10-16     117  503063688
# 1     2020-08-14     147  460919368
# 2     2020-06-08     150  426900000
# 3     2020-01-15     124  426505244
# 4     2020-08-22     150  363129000
# ..           ...     ...        ...
# 195   2020-07-02      91     215668
# 196   2020-02-12      99     208723
# 197   2020-10-22     109     206589
# 198   2020-07-03      94     178592
# 199   2020-07-01     101     177418
#
# [200 rows x 9 columns]

# %%
Total_2021_Movies
# Out:
#                             film     budget  \
# 0        Spider-Man: No Way Home  200000000
# 1    The Battle at Lake Changjin          0
# 2                        Hi, Mom   59000000
# 3                 No Time to Die  250000000
# 4                             F9  200000000
# ..                           ...        ...
# 195              Halloween Kills   20000000
# 196               The King's Man  100000000
# 197          The Addams Family 2          0
# 198                 Wrath of Man   40000000
# 199                          Old   18000000
#
#                                                 genres original_language  \
# 0    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 1    [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...                zh
# 2    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...                zh
# 3    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...                en
# 4    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# ..                                                 ...               ...
# 195  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 196  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 197  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...                en
# 198  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 199  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...                en
#
#      popularity                               production_companies  \
# 0      6855.906  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 1        12.254  [{'id': 159161, 'logo_path': None, 'name': 'Au...
# 2         7.446  [{'id': 69484, 'logo_path': '/2xtmvbEse87LM7OJ...
# 3       450.564  [{'id': 7576, 'logo_path': '/oYcUi1byZ312Z3xiz...
# 4       408.264  [{'id': 333, 'logo_path': '/5xUJfzPZ8jWJUDzYtI...
# ..          ...                                                ...
# 195     258.966  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 196    3739.757  [{'id': 5374, 'logo_path': '/iLu169q37KYJR7DAN...
# 197     284.103  [{'id': 21, 'logo_path': '/aOWKh4gkNrfFZ3Ep7n0...
# 198     303.146  [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsv...
# 199     203.747  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
#
#     release_date runtime     revenue
# 0     2021-12-15     148  1809940686
# 1     2021-09-30     176   888577720
# 2     2021-02-12     128   822049668
# 3     2021-09-29     163   774153007
# 4     2021-05-19     143   721077945
# ..           ...     ...         ...
# 195   2021-10-14     105   127000000
# 196   2021-12-22     131   124005195
# 197   2021-10-01      93   119815153
# 198   2021-04-22     119   103966489
# 199   2021-07-21     108    90112510
#
# [200 rows x 9 columns]

# %% [markdown]
# Importing Kaggle Dataset
# https://www.kaggle.com/c/tmdb-box-office-prediction/data?select=train.csv

# %%
data = pd.read_csv('train.csv')

# %%
data2= pd.read_csv('test.csv')

# %%
up_to_2019= pd.concat([data, data2])

# %%
up_to_2019
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 4393  7394                                                NaN  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                NaN  16000000
# 4396  7397                                                NaN   2000000
# 4397  7398                                                NaN     64000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4395                      [{'id': 18, 'name': 'Drama'}]
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 4397                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 4393                                NaN  tt0218922                en
# 4394                                NaN  tt0364751                en
# 4395                                NaN  tt0084855                en
# 4396                                NaN  tt3235888                en
# 4397                                NaN  tt0056663                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 4393  A young man is plunged into a life of subterfu...    9.970359  ...
# 4394  Three friends, whose lives have been drifting ...    6.046516  ...
# 4395  Frank Galvin is a down-on-his luck lawyer, red...    9.596883  ...
# 4396  For 19-year-old Jay, fall should be about scho...   20.359336  ...
# 4397  Twelve episodic tales in the life of a Parisia...   11.305910  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 4393       8/3/01   118.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4394      8/20/04    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4395      12/8/82   129.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4396       2/4/15   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4397      9/20/62    85.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 4393  Released  This is not a love story - it's a story about ...
# 4394  Released  The call of the wild, the thrill of adventure....
# 4395  Released  The doctors want to settle, the Church wants t...
# 4396  Released  It doesn't think, it doesn't feel, it doesn't ...
# 4397  Released  The many faces of a woman trying to find herse...
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397                              Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew     revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651.0
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435.0
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000.0
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000.0
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970.0
# ...                                                 ...         ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...         NaN
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...         NaN
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...         NaN
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...         NaN
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...         NaN
#
# [7398 rows x 23 columns]

# %%
up_to_2019 = up_to_2019.drop(columns=['belongs_to_collection', 'id','homepage','imdb_id','overview',
                                      'spoken_languages','status','tagline','original_title','Keywords','cast',
                                     'crew'])

# %%
up_to_2019= up_to_2019.drop(columns=['poster_path','production_countries'])

# %%
up_to_2019 = up_to_2019[['title','budget','genres','original_language','popularity',
                         'production_companies','release_date','runtime','revenue']]

# %%
up_to_2019.rename(columns={'title': 'film'}, inplace=True)

# %%
up_to_2019
# Out:
#                                           film    budget  \
# 0                       Hot Tub Time Machine 2  14000000
# 1     The Princess Diaries 2: Royal Engagement  40000000
# 2                                     Whiplash   3300000
# 3                                      Kahaani   1200000
# 4                                   Marine Boy         0
# ...                                        ...       ...
# 4393                              Original Sin  42000000
# 4394                          Without a Paddle  19000000
# 4395                               The Verdict  16000000
# 4396                                It Follows   2000000
# 4397                              Vivre Sa Vie     64000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]                en
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 4395                      [{'id': 18, 'name': 'Drama'}]                en
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 4397                      [{'id': 18, 'name': 'Drama'}]                fr
#
#       popularity                               production_companies  \
# 0       6.575393  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1       8.248895        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2      64.299990  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3       3.174936                                                NaN
# 4       1.148070                                                NaN
# ...          ...                                                ...
# 4393    9.970359  [{'name': 'Intermedia Films', 'id': 763}, {'na...
# 4394    6.046516  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4395    9.596883  [{'name': 'Twentieth Century Fox Film Corporat...
# 4396   20.359336  [{'name': 'Northern Lights Films', 'id': 8714}...
# 4397   11.305910  [{'name': 'Pathé Consortium Cinéma', 'id': 220...
#
#      release_date  runtime     revenue
# 0         2/20/15     93.0  12314651.0
# 1          8/6/04    113.0  95149435.0
# 2        10/10/14    105.0  13092000.0
# 3          3/9/12    122.0  16000000.0
# 4          2/5/09    118.0   3923970.0
# ...           ...      ...         ...
# 4393       8/3/01    118.0         NaN
# 4394      8/20/04     95.0         NaN
# 4395      12/8/82    129.0         NaN
# 4396       2/4/15    100.0         NaN
# 4397      9/20/62     85.0         NaN
#
# [7398 rows x 9 columns]

# %%
all_movies= pd.concat([up_to_2019, Total_2020_Movies, Total_2021_Movies], ignore_index=True, axis=0)

# %%
all_movies
# Out:
#                                           film     budget  \
# 0                       Hot Tub Time Machine 2   14000000
# 1     The Princess Diaries 2: Royal Engagement   40000000
# 2                                     Whiplash    3300000
# 3                                      Kahaani    1200000
# 4                                   Marine Boy          0
# ...                                        ...        ...
# 7793                           Halloween Kills   20000000
# 7794                            The King's Man  100000000
# 7795                       The Addams Family 2          0
# 7796                              Wrath of Man   40000000
# 7797                                       Old   18000000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 7793  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 7794  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 7795  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...                en
# 7796  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 7797  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...                en
#
#        popularity                               production_companies  \
# 0        6.575393  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        8.248895        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2       64.299990  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3        3.174936                                                NaN
# 4        1.148070                                                NaN
# ...           ...                                                ...
# 7793   258.966000  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 7794  3739.757000  [{'id': 5374, 'logo_path': '/iLu169q37KYJR7DAN...
# 7795   284.103000  [{'id': 21, 'logo_path': '/aOWKh4gkNrfFZ3Ep7n0...
# 7796   303.146000  [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsv...
# 7797   203.747000  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
#
#      release_date runtime     revenue
# 0         2/20/15    93.0  12314651.0
# 1          8/6/04   113.0  95149435.0
# 2        10/10/14   105.0  13092000.0
# 3          3/9/12   122.0  16000000.0
# 4          2/5/09   118.0   3923970.0
# ...           ...     ...         ...
# 7793   2021-10-14     105   127000000
# 7794   2021-12-22     131   124005195
# 7795   2021-10-01      93   119815153
# 7796   2021-04-22     119   103966489
# 7797   2021-07-21     108    90112510
#
# [7798 rows x 9 columns]

# %% [markdown]
# # Machine Learning Data Preprocessing

# %%
#import sklearn dependencies 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
all_movies.shape
# Out:
# (7798, 9)

# %%
all_movies = all_movies.dropna()

# %%
all_movies
# Out:
#                                           film     budget  \
# 0                       Hot Tub Time Machine 2   14000000
# 1     The Princess Diaries 2: Royal Engagement   40000000
# 2                                     Whiplash    3300000
# 6                               The Possession   14000000
# 8                       Muppet Treasure Island          0
# ...                                        ...        ...
# 7793                           Halloween Kills   20000000
# 7794                            The King's Man  100000000
# 7795                       The Addams Family 2          0
# 7796                              Wrath of Man   40000000
# 7797                                       Old   18000000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 8     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...                en
# ...                                                 ...               ...
# 7793  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 7794  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 7795  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...                en
# 7796  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 7797  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...                en
#
#        popularity                               production_companies  \
# 0        6.575393  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        8.248895        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2       64.299990  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 6        7.286477  [{'name': 'Ghost House Pictures', 'id': 768}, ...
# 8        6.902423  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ...           ...                                                ...
# 7793   258.966000  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 7794  3739.757000  [{'id': 5374, 'logo_path': '/iLu169q37KYJR7DAN...
# 7795   284.103000  [{'id': 21, 'logo_path': '/aOWKh4gkNrfFZ3Ep7n0...
# 7796   303.146000  [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsv...
# 7797   203.747000  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
#
#      release_date runtime     revenue
# 0         2/20/15    93.0  12314651.0
# 1          8/6/04   113.0  95149435.0
# 2        10/10/14   105.0  13092000.0
# 6         8/30/12    92.0  85446075.0
# 8         2/16/96   100.0  34327391.0
# ...           ...     ...         ...
# 7793   2021-10-14     105   127000000
# 7794   2021-12-22     131   124005195
# 7795   2021-10-01      93   119815153
# 7796   2021-04-22     119   103966489
# 7797   2021-07-21     108    90112510
#
# [3243 rows x 9 columns]

# %%
from numpy import mean
import time
from datetime import datetime
import calendar
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import re
from scipy.stats import pearsonr
import math
from statistics import median
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
all_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3243 entries, 0 to 7797
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film                  3243 non-null   object
#  1   budget                3243 non-null   object
#  2   genres                3243 non-null   object
#  3   original_language     3243 non-null   object
#  4   popularity            3243 non-null   float64
#  5   production_companies  3243 non-null   object
#  6   release_date          3243 non-null   object
#  7   runtime               3243 non-null   object
#  8   revenue               3243 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 253.4+ KB

# %% [markdown]
# Next we will need to perform a test train split.
# After data is split drop the revenue column from the test data because that will be our target variable in our models

# %%
train=all_movies.sample(frac=0.75,random_state=42) #random state is a seed value
test=all_movies.drop(train.index)

# %%
#drop Revenue column from TEST df because that will be our target variable
test=test.drop(columns=['revenue'])

# %%
X = all_movies[['budget', 'genres', 'original_language', 'popularity', 'production_companies', 'release_date', 'runtime']]
y = all_movies['revenue']

# %%
#take a look at the shape of our data
print ('The train data has {} rows and {} columns'.format(train.shape[0],train.shape[1]))
print ('---------------------------------------------')
print ('The test data has {} rows and {} columns'.format(test.shape[0],test.shape[1]))
# Out:
# The train data has 2432 rows and 9 columns
# ---------------------------------------------
# The test data has 811 rows and 8 columns

# %%
#make sure all missing values are gone
print("Training set missing values:\n", train.isna().sum())
print("\nTest set missing values:\n", test.isna().sum())
# Out:
# Training set missing values:
#  film                    0
# budget                  0
# genres                  0
# original_language       0
# popularity              0
# production_companies    0
# release_date            0
# runtime                 0
# revenue                 0
# dtype: int64
#
# Test set missing values:
#  film                    0
# budget                  0
# genres                  0
# original_language       0
# popularity              0
# production_companies    0
# release_date            0
# runtime                 0
# dtype: int64

# %% [markdown]
# # Data Exploration
# In this section we will take a look at our features to see how they may affect our outcome
# When conducting the original API pull, we only pulled key value pairs that we believed to be useful in our analysis. These pairs will be our features in the model.
# To get a better understanding of our variables we will produce box plots and histograms using matplotlib

# %%
print("Mean revenue: %.2f" % train.revenue.mean())
print("Median revenue: %.2f" % train.revenue.median())
# Out:
# Mean revenue: 78026500.25
# Median revenue: 19666523.00

# %%
#fix dtypes for analysis

# %%
train['revenue'] = train.revenue.astype(float)

# %%
train['budget'] = train.budget.astype(int)
test['budget'] = test.budget.astype(int)

# %%
train['runtime'] = train.runtime.astype(float)
test['runtime'] = test.runtime.astype(float)

# %%
train.dtypes
# Out:
# film                     object
# budget                    int64
# genres                   object
# original_language        object
# popularity              float64
# production_companies     object
# release_date             object
# runtime                 float64
# revenue                 float64
# dtype: object

# %%
#create histograms of the revenue to get a better idea of the distribution 
f, ax = plt.subplots(3, figsize=(10,6))

sns.set(rc={'figure.figsize':(12,8)})
sns.boxplot(x=train.revenue, ax = ax[0], color='indianred')
ax[0].set_title("Box Plot of revenue variable")
sns.distplot(a=train.revenue, kde = False, ax = ax[1], color='indianred', hist_kws=dict(alpha=1))
ax[1].set_title("Histogram of revenue variable")
sns.distplot(a=np.log1p(train.revenue), kde = False, ax = ax[2], color='indianred', hist_kws=dict(alpha=1))
ax[2].set_title("Log1p transformed revenue Histogram")
f.tight_layout()
# Out:
# /Users/meredithgray/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#the revenue should not be this small
train.revenue.nsmallest(20)
# Out:
# 1917     1.0
# 1754     1.0
# 347      1.0
# 695      2.0
# 1541     3.0
# 1346     5.0
# 2490     6.0
# 1190     7.0
# 639      8.0
# 2251     8.0
# 2582     8.0
# 280     10.0
# 312     12.0
# 450     12.0
# 2399    15.0
# 150     18.0
# 2090    18.0
# 1884    23.0
# 2032    25.0
# 1138    30.0
# Name: revenue, dtype: float64

# %% [markdown]
# We have a hypothesis that budget will have a massive impact on a films revenue

# %%
#plotting the data
f, ax = plt.subplots(2, figsize=(10,10))

sns.set(rc={'figure.figsize':(12,8)})
sns.boxplot(x=train.budget, ax = ax[0], color='violet')
ax[0].set_title("Box Plot of Budget Feature")
sns.distplot(a=train.budget, kde = False, ax = ax[1], color='violet', hist_kws=dict(alpha=1))
ax[1].set_title("Histogram of Budget Feature")
f.tight_layout()
# Out:
# /Users/meredithgray/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print('Movies with budget listed as 0: ',(train.budget == 0).sum())
# Out:
# Movies with budget listed as 0:  682

# %% [markdown]
# The distribution on budget in the training set is also heavily skewed right for similar reasons to revenue, so we also look at the log transformed distribution. Additionally, while there are no movies missing a budget, there are over 800 movies in our training set that have a budget of 0. This is highly unlikely to be accurate as every produced film has some kind of budget, so it is likely that the films where the budget was not found were replaced with 0. To clean up this data, we will replace these 0 values with the median budget to reduce the skew.

# %%
median = train.loc[train['budget'] > 0, 'budget'].median()
train["budget_processed"] = train["budget"].mask(train["budget"] == 0, median)
test["budget_processed"] = test["budget"].mask(test["budget"] == 0, median)

# %% [markdown]
# There seem to be a lot of bad values beyond just the ones that equal 0. We will also replace all values for budget under 10,000 USD since this is a reasonabe minimum value. No major feature films are reasonably produced for under 10,000 USD, and one of the most famous examples of a successful low budget film was The Blair Witch Project, which still had a 40,000 USD budget.

# %%
median = train.loc[train['budget'] >= 10000, 'budget'].median()
train["budget_processed"] = train["budget"].mask(train["budget"] < 10000, median)
test["budget_processed"] = test["budget"].mask(test["budget"] < 10000, median)

# %%
#plotting the data
f, ax = plt.subplots(2, figsize=(10,6))

sns.set(rc={'figure.figsize':(12,8)})
sns.boxplot(x=train.budget_processed, ax = ax[0], color='mediumaquamarine')
ax[0].set_title("Box Plot of budget_processed variable")
sns.distplot(a=train.budget_processed, kde = False, ax = ax[1], color='mediumaquamarine', hist_kws=dict(alpha=1))
ax[1].set_title("Histogram of budget_processed variable")
f.tight_layout()
# Out:
# /Users/meredithgray/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Since there were so many values that are under 10,000 in the budget column, there is a huge cluster of data at this median value. Meaning this was not a good solution

# %%
#look at bivariate analysis between revenue and budget
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.scatter(train['budget_processed'], train['revenue'], color='mediumaquamarine')
plt.title('Revenue vs budget_processed');

# %%
#viewing the correlation between budget and revenue
corr, _ = pearsonr(train['budget_processed'], train['revenue'])
print('Pearsons correlation between budget(edited) and revenue: %.3f' % corr)
# Out:
# Pearsons correlation between budget(edited) and revenue: 0.692

# %% [markdown]
# Pretty Strong Correlation

# %%
train['genres'] = train.genres.astype(str)
test['genres'] = test.genres.astype(str)

# %%
#genres
#Different genres may perform differently in the box office
#messy layout of this column, needs to be cleaned 
train['genres_reform'] = train['genres'].apply(lambda x:re.findall("'name': \'(.+?)\'", x))
test['genres_reform'] = test['genres'].apply(lambda x:re.findall("'name': \'(.+?)\'", x))

# %%
train.dtypes
# Out:
# film                     object
# budget                    int64
# genres                   object
# original_language        object
# popularity              float64
# production_companies     object
# release_date             object
# runtime                 float64
# revenue                 float64
# budget_processed        float64
# genres_reform            object
# dtype: object

# %%
train
# Out:
#                                                    film     budget  \
# 2729                                      The Boss Baby  125000000
# 7674                                     The King's Man  100000000
# 1189                                 The Gorgeous Hussy    1119000
# 345                              Arthur 2: On the Rocks          0
# 7398  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...   15800000
# ...                                                 ...        ...
# 1949                                     Paris Can Wait    5000000
# 1859                             Katy Perry: Part of Me   12000000
# 1166                                            Niagara    1250000
# 2087                                             Oculus    5000000
# 7517                           God, You’re Such a Prick          0
#
#                                                  genres original_language  \
# 2729  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 7674  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 1189  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...                en
# 345   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...                en
# 7398  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...                ja
# ...                                                 ...               ...
# 1949  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                en
# 1859  [{'id': 99, 'name': 'Documentary'}, {'id': 104...                en
# 1166  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                en
# 2087                     [{'id': 27, 'name': 'Horror'}]                en
# 7517  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...                de
#
#        popularity                               production_companies  \
# 2729    13.392824  [{'name': 'Twentieth Century Fox Film Corporat...
# 7674  3739.757000  [{'id': 5374, 'logo_path': '/iLu169q37KYJR7DAN...
# 1189     0.948775  [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...
# 345      3.611453             [{'name': 'Warner Bros.', 'id': 6194}]
# 7398  1169.173000  [{'id': 5887, 'logo_path': '/m6FEqz8rQECnmfjEw...
# ...           ...                                                ...
# 1949     8.966129          [{'name': 'American Zoetrope', 'id': 70}]
# 1859     8.960713  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1166    14.605464  [{'name': 'Twentieth Century Fox Film Corporat...
# 2087     8.698043  [{'name': 'Intrepid Pictures', 'id': 1224}, {'...
# 7517     7.320000  [{'id': 2462, 'logo_path': None, 'name': 'Cact...
#
#      release_date  runtime      revenue  budget_processed  \
# 2729      3/23/17     97.0  498814908.0       125000000.0
# 7674   2021-12-22    131.0  124005195.0       100000000.0
# 1189      8/28/36    103.0    2019000.0         1119000.0
# 345        7/8/88    113.0   14681192.0        20000000.0
# 7398   2020-10-16    117.0  503063688.0        15800000.0
# ...           ...      ...          ...               ...
# 1949      9/12/16     92.0    6700000.0         5000000.0
# 1859      6/28/12     93.0   32726956.0        12000000.0
# 1166      1/26/53     92.0    8500000.0         1250000.0
# 2087       9/8/13    104.0   44030246.0         5000000.0
# 7517   2020-10-01     98.0    2430000.0        20000000.0
#
#                                 genres_reform  Comedy
# 2729              [Animation, Comedy, Family]       0
# 7674       [Action, Adventure, Thriller, War]       0
# 1189                         [Drama, History]       0
# 345                         [Comedy, Romance]       0
# 7398  [Animation, Action, Adventure, Fantasy]       0
# ...                                       ...     ...
# 1949                         [Drama, Romance]       0
# 1859                     [Documentary, Music]       0
# 1166                 [Crime, Drama, Thriller]       0
# 2087                                 [Horror]       0
# 7517                 [Romance, Drama, Comedy]       0
#
# [2432 rows x 12 columns]

# %%
# Function to unpack all of the different genres into unique columns
def unpackCol(list, df):
    for i in range(len(df)):
        for name in list[i]:
            if name not in df.columns:
                df[name] = 0
            df[name][i] = 1
    return df

# %%
df = pd.DataFrame()
df = unpackCol(train['genres_reform'], train)

print(df.columns)
# Out:
# <ipython-input-134-eb3ee23b2f19>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name][i] = 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-1401bd8af18a> in <module>
#       1 df = pd.DataFrame()
# ----> 2 df = unpackCol(train['genres_reform'], train)
#       3
#       4 print(df.columns)
#
# <ipython-input-134-eb3ee23b2f19> in unpackCol(list, df)
#       2 def unpackCol(list, df):
#       3     for i in range(len(df)):
# ----> 4         for name in list[i]:
#       5             if name not in df.columns:
#       6                 df[name] = 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 1
